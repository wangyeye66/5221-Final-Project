# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
df =  pd.read_csv('all_stocks_5yr.csv')

# %%
df.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
df.shape
# Out:
# (619040, 7)

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name'], dtype='object')

# %%
AAL = df[df['Name'] == 'AAL']

# %%
AAL.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
AAL.shape
# Out:
# (1259, 7)

# %%
ALL_1 = AAL[['date','close']]
ALL_1['date'] = pd.to_datetime(ALL_1['date'], format="%Y/%m/%d")
# Out:
# C:\Users\daizi\AppData\Local\Temp/ipykernel_13708/2743534012.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ALL_1['date'] = pd.to_datetime(ALL_1['date'], format="%Y/%m/%d")

# %%
ALL_1.head()
# Out:
#         date  close
# 0 2013-02-08  14.75
# 1 2013-02-11  14.46
# 2 2013-02-12  14.27
# 3 2013-02-13  14.66
# 4 2013-02-14  13.99

# %%
ALL_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1259 entries, 0 to 1258
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1259 non-null   datetime64[ns]
#  1   close   1259 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 29.5 KB

# %%
ALL_1.isnull().sum()
# Out:
# date     0
# close    0
# dtype: int64

# %%
fig, ax = plt.subplots(figsize=(14,5))
ax.plot(ALL_1['date'], ALL_1['close'])
ax.set_xlabel("Date")
ax.set_ylabel("Stock Price")
ax.set_title("All Close Price History Of AAL")
# Out:
# Text(0.5, 1.0, 'All Close Price History Of AAL')

# %%
fig, axes = plt.subplots(figsize=(14,5))
axes.plot(ALL_1.close.diff()); axes.set_title('1st Order Differencing')
# Out:
# Text(0.5, 1.0, '1st Order Differencing')

# %%
fig, axes = plt.subplots(figsize=(14,5))
axes.plot(ALL_1.close.diff().diff().diff()); axes.set_title('3rd Order Differencing')
# Out:
# Text(0.5, 1.0, '3rd Order Differencing')

# %%
plot_acf(ALL_1.close.diff().diff().dropna())

# %%
plot_pacf(ALL_1.close.diff().diff().dropna())

# %% [markdown]
# ---

# %% [markdown]
# ARIMA

# %%
from statsmodels.tsa.arima_model import ARIMA

model = ARIMA(ALL_1.close, order=(2,1,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\tsa\arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.close   No. Observations:                 1258
# Model:                 ARIMA(2, 1, 1)   Log Likelihood               -1600.916
# Method:                       css-mle   S.D. of innovations              0.864
# Date:                Thu, 06 Apr 2023   AIC                           3211.832
# Time:                        01:24:37   BIC                           3237.518
# Sample:                             1   HQIC                          3221.485
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0291      0.026      1.109      0.267      -0.022       0.081
# ar.L1.D.close    -0.7951      0.207     -3.845      0.000      -1.200      -0.390
# ar.L2.D.close     0.0711      0.028      2.510      0.012       0.016       0.127
# ma.L1.D.close     0.8597      0.206      4.179      0.000       0.457       1.263
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.1413           +0.0000j            1.1413            0.5000
# AR.2           12.3236           +0.0000j           12.3236            0.0000
# MA.1           -1.1632           +0.0000j            1.1632            0.5000
# -----------------------------------------------------------------------------

# %%
model_fit.plot_predict(dynamic=False)
plt.show()
