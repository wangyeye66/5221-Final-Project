# %% [markdown]
# # GR 5221 Final Project

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import math
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARIMA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %% [markdown]
# ## Section 1: Exloratory Analysis

# %% [markdown]
# ### 1.1 Load Data

# %%
df =  pd.read_csv('all_stocks_5yr.csv')
df.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
df.columns
# Out:
# Index(['date', 'open', 'high', 'low', 'close', 'volume', 'Name'], dtype='object')

# %% [markdown]
# ### 1.2 Reframe the dataframe
# - Choose company `AAL` only
# - Choose column `date` and `close`

# %%
AAL = df[df['Name'] == 'AAL']
ALL_1 = AAL.loc[:, ['date', 'close']]
ALL_1['date'] = pd.to_datetime(ALL_1['date'], format="%Y/%m/%d")
ALL_1.head()
# Out:
#         date  close
# 0 2013-02-08  14.75
# 1 2013-02-11  14.46
# 2 2013-02-12  14.27
# 3 2013-02-13  14.66
# 4 2013-02-14  13.99

# %% [markdown]
# There is no null value in the dataframe.

# %%
ALL_1.isnull().sum()
# Out:
# date     0
# close    0
# dtype: int64

# %%
ALL_1.shape
# Out:
# (1259, 2)

# %% [markdown]
# ### 1.3 Visualization

# %%
fig, ax = plt.subplots(figsize=(14,5))
ax.plot(ALL_1['date'], ALL_1['close'])
ax.set_xlabel("Date")
ax.set_ylabel("Stock Price")
ax.set_title("All Close Price History Of AAL")
# Out:
# Text(0.5, 1.0, 'All Close Price History Of AAL')

# %% [markdown]
# ---

# %% [markdown]
# #### Null Hypothesis (H0): If failed to be rejected, it suggests the time series has a unit root, meaning it is non-stationary. It has some time dependent structure.
#
# #### Alternate Hypothesis (H1): The null hypothesis is rejected; it suggests the time series does not have a unit root, meaning it is stationary. It does not have time-dependent structure.

# %%
result = adfuller(ALL_1['close'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: -2.066675
# p-value: 0.258124

# %% [markdown]
# #### p-value: 0.258124 > 0.05, we faill toreject Null hypothesis.

# %%
plot_acf(ALL_1['close'], lags=range(1, len(ALL_1['close'])))
plt.xlabel('Lag')
plt.ylabel('Autocorrelation')
plt.title('Autocorrelation Function (ACF) for ALL')
plt.show()

# %% [markdown]
# ### Detrending and Seasonality

# %%
y = ALL_1['close']
X = np.arange(len(y)).reshape(-1, 1)

# %%
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
trend = regressor.predict(X)

# %%
len(trend)
# Out:
# 1259

# %%
ALL_1['trend'] = trend
detrended_data = y - trend

# %%
plt.figure(figsize=(12, 6))
plt.plot(X, y, label='Original Data')
plt.plot(X, trend, label='Trend')
plt.plot(X, detrended_data, label='Detrended Data')
plt.legend()
plt.xlabel('Time')
plt.ylabel('Data')
plt.title('Original Data, Trend, and Detrended Data')
plt.show()

# %% [markdown]
# ## Section 2: Time Series Model and Modeling Process
# ### 2.1 AR(1) and MA(1)

# %%
from statsmodels.tsa.arima.model import ARIMA
# model1 is AR(1)
model1 = ARIMA(ALL_1.close, order = (1,1,0))
# model2 is MA(1)
model2 = ARIMA(ALL_1.close, order = (0,1,1))
model_fit1 = model1.fit()
model_fit2 = model2.fit()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
pred1 = model_fit1.predict(dynamic = False)
pred2 = model_fit2.predict(dynamic = False)
plt.style.use('ggplot')

# plot actual values and predicted values
ax1.plot(pred1[1:], label='Predicted', alpha = 0.8)
ax1.plot(ALL_1.close, label='Actual', alpha = 0.5)
ax1.set_title('AR(1) Model')
ax1.set_xlabel('Data')
ax1.set_ylabel('Value')
ax1.legend()


ax2.plot(pred2[1:], label='Predicted', alpha = 0.8)
ax2.plot(ALL_1.close, label='Actual', alpha = 0.5)
ax2.set_title('MA(1) Model')
ax2.set_xlabel('Data')
ax2.set_ylabel('Value')
ax2.legend()

plt.show()

# %% [markdown]
# The lower the value of the Root Mean Squared Error, the better the model is.(...)

# %%
from sklearn.metrics import mean_squared_error

rmse = np.sqrt(mean_squared_error(ALL_1.close[1:], pred1[1:]))
rmse2 = np.sqrt(mean_squared_error(ALL_1.close[1:], pred2[1:]))
print(f'The Root Mean Squared Error for AR(1) model is {rmse}\nThe Root Mean Squared Error for MA(1) model is {rmse2}')
# Out:
# The Root Mean Squared Error for AR(1) model is 0.8646704398975732
# The Root Mean Squared Error for MA(1) model is 0.8647742633780344

# %% [markdown]
# ## 2.3 ARIMA

# %%
fig, axes = plt.subplots(3, 2, figsize=(15, 12), dpi=120)

#1st Order Differencing
axes[0, 0].plot(ALL_1.close.diff().dropna());axes[0, 0].set_title('1st Order Differencing')

plot_acf(ALL_1.close.diff().dropna(), ax=axes[1, 0], lags=600)
axes[1, 0].set_title('ACF of 1st Order Differencing')

plot_pacf(ALL_1.close.diff().dropna(), method='ywm',ax=axes[2, 0], lags=600)
axes[2, 0].set_title('PACF of 1st Order Differencing')


#2nd Order Differencing
axes[0, 1].plot(ALL_1.close.diff().diff().dropna());axes[0, 1].set_title('2nd Order Differencing')

plot_acf(ALL_1.close.diff().diff().dropna(), ax=axes[1, 1], lags=600)
axes[1, 1].set_title('ACF of 2nd Order Differencing')

plot_pacf(ALL_1.close.diff().diff().dropna(), method='ywm',ax=axes[2, 1], lags=600)
axes[2, 1].set_title('PACF of 2nd Order Differencing')



fig.tight_layout()
plt.show()

# %% [markdown]
# - From above plots, we can see that the time series reaches stationarity with one orders of differencing.

# %% [markdown]
# #### Dickey-Fuller test

# %% [markdown]
# - For 1st Order Differencing|

# %%
result_1 = adfuller(ALL_1.close.diff().dropna())
print('ADF Statistic: %f' % result_1[0])
print('p-value: %f' % result_1[1])
# Out:
# ADF Statistic: -33.199423
# p-value: 0.000000

# %% [markdown]
# - For 2nd Order Differencing

# %%
result_2 = adfuller(ALL_1.close.diff().diff().dropna())
print('ADF Statistic: %f' % result_2[0])
print('p-value: %f' % result_2[1])
# Out:
# ADF Statistic: -13.149203
# p-value: 0.000000

# %% [markdown]
# #### From Dickey_fuller test both difference are stationary

# %% [markdown]
# ---

# %%
model3 = ARIMA(ALL_1.close, order = (1,1,1))
model_fit3 = model3.fit()
print(model_fit3.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 1259
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -1601.880
# Date:                Mon, 24 Apr 2023   AIC                           3209.761
# Time:                        23:31:44   BIC                           3225.173
# Sample:                             0   HQIC                          3215.553
#                                - 1259
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2768      0.346      0.800      0.424      -0.402       0.955
# ma.L1         -0.2107      0.352     -0.599      0.549      -0.901       0.479
# sigma2         0.7474      0.021     36.346      0.000       0.707       0.788
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               278.95
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.92   Skew:                            -0.21
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model3 = ARIMA(ALL_1.close, order = (1,1,3))
model_fit3 = model3.fit()
print(model_fit3.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 1259
# Model:                 ARIMA(1, 1, 3)   Log Likelihood               -1600.415
# Date:                Mon, 24 Apr 2023   AIC                           3210.830
# Time:                        23:31:45   BIC                           3236.516
# Sample:                             0   HQIC                          3220.483
#                                - 1259
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8472      0.163      5.184      0.000       0.527       1.167
# ma.L1         -0.7838      0.163     -4.794      0.000      -1.104      -0.463
# ma.L2         -0.0237      0.035     -0.683      0.495      -0.092       0.044
# ma.L3         -0.0500      0.027     -1.834      0.067      -0.103       0.003
# sigma2         0.7456      0.021     35.959      0.000       0.705       0.786
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               272.73
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.92   Skew:                            -0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model3 = ARIMA(ALL_1.close, order = (2,1,3))
model_fit3 = model3.fit()
print(model_fit3.summary())
# Out:
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 1259
# Model:                 ARIMA(2, 1, 3)   Log Likelihood               -1598.123
# Date:                Mon, 24 Apr 2023   AIC                           3208.247
# Time:                        23:40:51   BIC                           3239.070
# Sample:                             0   HQIC                          3219.831
#                                - 1259
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.6968      0.021    -32.821      0.000      -0.738      -0.655
# ar.L2         -0.9700      0.020    -49.324      0.000      -1.009      -0.931
# ma.L1          0.7586      0.032     23.491      0.000       0.695       0.822
# ma.L2          1.0117      0.029     35.178      0.000       0.955       1.068
# ma.L3          0.0421      0.026      1.619      0.105      -0.009       0.093
# sigma2         0.7445      0.021     36.263      0.000       0.704       0.785
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               287.10
# Prob(Q):                              0.88   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.91   Skew:                            -0.20
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
residuals = pd.DataFrame(model_fit3.resid)

# %%
fig, ax = plt.subplots(1,2,figsize=(15, 5))
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %% [markdown]
# ### AIC

# %%
best_p = None
best_q = None
best_aic = np.inf

# Define the range of values for p and q to search over
p_values = range(0, 6) # Example: searching for p values from 0 to 5
q_values = range(0, 6) # Example: searching for q values from 0 to 5

for p in p_values:
    for q in q_values:
        try:
            # Fit ARIMA model with current p and q values
            model = ARIMA(ALL_1.close, order=(p, 1, q)) # Assuming d=1 (i.e., first-order differencing)
            model_fit = model.fit()
            aic = model_fit.aic
            
            # Update best p and q values if current AIC is better
            if aic < best_aic:
                best_p = p
                best_q = q
                best_aic = aic

        except:
            continue

print("Best p:", best_p)
print("Best q:", best_q)
# Out:
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Best p: 1
# Best q: 0
# C:\Users\daizi\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# ## Auto arima to choose q and p

# %%
from pmdarima.arima import auto_arima

# %%
model = auto_arima(ALL_1.close, seasonal=True, suppress_warnings=True,
                   stepwise=True, trace=True, error_action="ignore", 
                   max_order=None, suppress_stderr=False, 
                   random_state=None, n_fits=10)

# Print the optimal ARIMA model order
print("Best ARIMA model order: (p, d, q) =", model.order)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=3212.973, Time=0.80 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3212.261, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=3208.962, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=3209.245, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3211.684, Time=0.04 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=3210.192, Time=0.15 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=3210.554, Time=0.14 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=3211.797, Time=0.47 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=3208.210, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=3209.380, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=3209.761, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=3208.511, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=3211.060, Time=0.61 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 2.811 seconds
# Best ARIMA model order: (p, d, q) = (1, 1, 0)

# %%
model3 = ARIMA(ALL_1.close, order = (1,1,0))
model_fit3 = model3.fit()
print(model_fit3.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 1259
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               -1602.105
# Date:                Mon, 24 Apr 2023   AIC                           3208.210
# Time:                        23:37:43   BIC                           3218.484
# Sample:                             0   HQIC                          3212.071
#                                - 1259
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0659      0.025      2.680      0.007       0.018       0.114
# sigma2         0.7476      0.021     36.365      0.000       0.707       0.788
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               280.01
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.92   Skew:                            -0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## Section 3: Forecasting

# %% [markdown]
# ### 4.1 Forecasting using ARIMA

# %%
from statsmodels.tsa.stattools import acf

# %%
train_size = 0.8  
train, test = train_test_split(ALL_1.close, train_size=train_size, shuffle=False)

# %%
model5 = ARIMA(train, order=(1, 1, 0))  
fitted = model5.fit()  
print(fitted.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  close   No. Observations:                 1007
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               -1273.487
# Date:                Mon, 24 Apr 2023   AIC                           2550.974
# Time:                        23:35:30   BIC                           2560.801
# Sample:                             0   HQIC                          2554.708
#                                - 1007
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0680      0.027      2.508      0.012       0.015       0.121
# sigma2         0.7363      0.022     33.275      0.000       0.693       0.780
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               268.74
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.43   Skew:                            -0.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.48
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
fc, se, conf = fitted.forecast(len(test), alpha=0.05)  # 95% conf
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10116/489578163.py in <module>
# ----> 1 fc, se, conf = fitted.forecast(len(test), alpha=0.05)  # 95% conf
#
# ValueError: too many values to unpack (expected 3)

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# ### 4.2 Forecasting using LSTM

# %%
conda update pip

# %%
pip -V
# Out:
# pip 22.3.1 from C:\Users\daizi\AppData\Roaming\Python\Python39\site-packages\pip (python 3.9)
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow==2.8
# Out:
# Collecting tensorflow==2.8Note: you may need to restart the kernel to use updated packages.
#   Downloading tensorflow-2.8.0-cp39-cp39-win_amd64.whl (438.0 MB)
#      -------------------------------------- 438.0/438.0 MB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (3.19.4)
# Requirement already satisfied: flatbuffers>=1.12 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (2.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (13.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (1.44.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\daizi\anaconda3\lib\site-packages (from tensorflow==2.8) (1.22.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\daizi\anaconda3\lib\site-packages (from tensorflow==2.8) (3.10.0.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\daizi\anaconda3\lib\site-packages (from tensorflow==2.8) (1.12.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\daizi\anaconda3\lib\site-packages (from tensorflow==2.8) (1.16.0)
# Requirement already satisfied: gast>=0.2.1 in c:\users\daizi\anaconda3\lib\site-packages (from tensorflow==2.8) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (0.24.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (1.0.0)
# Collecting keras<2.9,>=2.8.0rc0
#   Using cached keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
# Requirement already satisfied: tf-estimator-nightly==2.8.0.dev2021122109 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (2.8.0.dev2021122109)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\daizi\anaconda3\lib\site-packages (from tensorflow==2.8) (3.2.1)
# Collecting tensorboard<2.9,>=2.8
#   Using cached tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (0.2.0)
# Requirement already satisfied: setuptools in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (65.6.3)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (1.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorflow==2.8) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from astunparse>=1.6.0->tensorflow==2.8) (0.38.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.28.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.6.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\daizi\anaconda3\lib\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from tensorboard<2.9,>=2.8->tensorflow==2.8) (3.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\daizi\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8) (4.8.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\daizi\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow==2.8) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\daizi\appdata\roaming\python\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow==2.8) (3.2.0)
# Installing collected packages: keras, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.11.0
#     Uninstalling keras-2.11.0:
#       Successfully uninstalled keras-2.11.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.11.0
#     Uninstalling tensorboard-2.11.0:
#       Successfully uninstalled tensorboard-2.11.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.11.0
#     Uninstalling tensorflow-2.11.0:
#       Successfully uninstalled tensorflow-2.11.0
# Successfully installed keras-2.8.0 tensorboard-2.8.0 tensorflow-2.8.0
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\daizi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\daizi\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -tatsmodels (c:\users\daizi\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -tatsmodels (c:\users\daizi\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -tatsmodels (c:\users\daizi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\daizi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\daizi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\daizi\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.11.0 requires keras<2.12,>=2.11.0, but you have keras 2.8.0 which is incompatible.
# tensorflow-intel 2.11.0 requires tensorboard<2.12,>=2.11, but you have tensorboard 2.8.0 which is incompatible.
#
# [notice] A new release of pip available: 22.3.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17452/1952916621.py in <module>
#       1 from sklearn.preprocessing import MinMaxScaler
# ----> 2 from keras.models import Sequential
#       3 from keras.layers import LSTM, Dense
#
# ~\anaconda3\lib\site-packages\keras\__init__.py in <module>
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# ~\anaconda3\lib\site-packages\keras\models\__init__.py in <module>
#      16
#      17
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# ~\anaconda3\lib\site-packages\keras\engine\functional.py in <module>
#      24 import tensorflow.compat.v2 as tf
#      25
# ---> 26 from keras import backend
#      27 from keras.dtensor import layout_map as layout_map_lib
#      28 from keras.engine import base_layer
#
# ~\anaconda3\lib\site-packages\keras\backend.py in <module>
#      32 from keras import backend_config
#      33 from keras.distribute import distribute_coordinator_utils as dc
# ---> 34 from keras.engine import keras_tensor
#      35 from keras.utils import control_flow_util
#      36 from keras.utils import object_identity
#
# ~\anaconda3\lib\site-packages\keras\engine\keras_tensor.py in <module>
#      17 import tensorflow.compat.v2 as tf
#      18
# ---> 19 from keras.utils import object_identity
#      20
#      21 # isort: off
#
# ~\anaconda3\lib\site-packages\keras\utils\__init__.py in <module>
#      46
#      47 # Internal
# ---> 48 from keras.utils.layer_utils import get_source_inputs
#      49
#      50 # Deprecated
#
# ~\anaconda3\lib\site-packages\keras\utils\layer_utils.py in <module>
#      24 import tensorflow.compat.v2 as tf
#      25
# ---> 26 from keras import initializers
#      27 from keras.utils import io_utils
#      28
#
# ~\anaconda3\lib\site-packages\keras\initializers\__init__.py in <module>
#      20
#      21 from keras.initializers import initializers_v1
# ---> 22 from keras.initializers import initializers_v2
#      23 from keras.saving.legacy import serialization
#      24 from keras.utils import generic_utils
#
# ~\anaconda3\lib\site-packages\keras\initializers\initializers_v2.py in <module>
#      21
#      22 from keras import backend
# ---> 23 from keras.dtensor import utils
#      24
#      25 # isort: off
#
# ~\anaconda3\lib\site-packages\keras\dtensor\__init__.py in <module>
#      20 # Conditional import the dtensor API, since it is currently broken in OSS.
#      21 if _DTENSOR_API_ENABLED:
# ---> 22     from tensorflow.compat.v2.experimental import dtensor as dtensor_api
#      23 else:
#      24     # Leave it with a placeholder, so that the import line from other python
#
# ImportError: cannot import name 'dtensor' from 'tensorflow.compat.v2.experimental' (C:\Users\daizi\AppData\Roaming\Python\Python39\site-packages\tensorflow\_api\v2\compat\v2\experimental\__init__.py)

# %% [markdown]
# ## Section 5: ~
